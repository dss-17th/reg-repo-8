# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
import matplotlib.pyplot as plt
import missingno as msno
# %matplotlib inline

# %%
# !pip install missingno
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/riversong/miniforge3/envs/ml/include/python3.8/UNKNOWN
# sysconfig: /Users/riversong/miniforge3/envs/ml/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/riversong/miniforge3/envs/ml/include/python3.8/UNKNOWN
# sysconfig: /Users/riversong/miniforge3/envs/ml/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...

# %%
# 나잇대 histogram
sns.distplot(F['age'], bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.distplot(F['MotM'], bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='MotM'>

# %%
# height 의 histogram
F['height'] = F['height'].astype(int)
sns.distplot(F['height'], bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='height'>

# %%
# AerialsWon 의 histogram
sns.distplot(F['AerialsWon'], bins=20, kde=False)
# Out:
# <AxesSubplot:xlabel='AerialsWon'>

# %%
F['agent'].value_counts()
# Out:
# ICM Stellar Sports           60
# Wasserman                    40
# Unique Sports Management     39
# Gestifute                    25
# CAA Base Ltd                 21
#                              ..
# 11WINS                        1
# F-F SPORT                     1
# MLA Management                1
# Soccer Vision BV              1
# Cristiano Simões              1
# Name: agent, Length: 187, dtype: int64

# %%
# outfitter (협찬 브랜드)의 countplot
sns.countplot(F['outfitter'] )
# Out:
# <AxesSubplot:xlabel='outfitter', ylabel='count'>

# %%
pre = pre[['market_value', 'app', 'conceded_goals', 'clean_sheets', 'yellow_card',
       'second_yell', 'red_card', 'age', 'height', 'sns',
       'Tackles', 'Inter', 'Fouls', 'Offsides', 'Clear', 'Drbed', 'Blocks',
       'OwnG', 'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB',
       'Rating_y', 'Goals', 'SpG', 'Drb', 'Fouled', 'Off', 'Disp', 'UnsTch',
       'AerialsWon', 'MotM']]
plt.figure(figsize=(15,15))
sns.heatmap(data = pre.corr(), annot=True, 
fmt = '.1f', linewidths=.5, cmap='Blues')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a9be7f6542a8> in <module>
# ----> 1 pre = pre[['market_value', 'app', 'conceded_goals', 'clean_sheets', 'yellow_card',
#       2        'second_yell', 'red_card', 'age', 'height', 'sns',
#       3        'Tackles', 'Inter', 'Fouls', 'Offsides', 'Clear', 'Drbed', 'Blocks',
#       4        'OwnG', 'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB',
#       5        'Rating_y', 'Goals', 'SpG', 'Drb', 'Fouled', 'Off', 'Disp', 'UnsTch',
#
# NameError: name 'pre' is not defined

# %%
final['']

# %%
player['MotM'] = player['MotM'].replace('-',0)
player['MotM'] = player['MotM'].fillna(0)
player['MotM'] = player['MotM'].astype(int)

sns.distplot(player['MotM'], bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='MotM'>

# %%
# MotM(Match of the Man)의 결측치 처리
player['MotM'] = player['MotM'].replace('-',0)
player['MotM'] = player['MotM'].fillna(0)
player['MotM'] = player['MotM'].astype(int)

# AerialWon의 결측치 처리
player['AerialsWon'] = player['AerialsWon'].replace('-',0)
player['AerialsWon'] = player['AerialsWon'].fillna(0)
player['AerialsWon'] = player['AerialsWon'].astype(float)

sns.distplot(player['AerialsWon'], bins=10, kde=False)
# Out:
# <AxesSubplot:xlabel='AerialsWon'>

# %%
plt.figure(figsize=(15,15))
plt.scatter(player["age"],player["market_value"], color='skyblue', alpha=0.5, s=200*player.Rating_y)

# %%
plt.figure(figsize=(7,7))
plt.scatter(player["MotM"],player["market_value"], color='skyblue', alpha=0.5)

# %%
plt.figure(figsize=(7,7))
plt.scatter(player["PS%"],player["market_value"], color='skyblue', alpha=0.5)

# %%
player['PS%'] = player['PS%'].astype(float)

# %%
plt.scatter(player["Rating_y"],player["market_value"], color='skyblue', alpha=0.5)
