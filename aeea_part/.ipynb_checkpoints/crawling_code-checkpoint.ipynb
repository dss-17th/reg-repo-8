# %%
import time
import pickle
import numpy as np
import pandas as pd
import urllib.parse
import requests
import platform
import matplotlib.pyplot as plt
import missingno as msno

from fake_useragent import UserAgent
from bs4 import BeautifulSoup
from matplotlib import font_manager, rc


plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Linux':
    rc('font', family='NanumBarunGothic')
else:
    print('Unknown system... sorry~~')

# %%
cols = ['name', 'market_value', 'app', 'conceded_goals', 'clean_sheets',
        'yellow_card', 'second_yell', 'red_card', 'age', 'height', 'citizenship',
        'position', 'foot', 'agent', 'club', 'joined', 'expire', 'last_contract',
        'outfitter','sns','caps_goals']

# %%
df = pd.DataFrame(columns=cols)
df
# Out:
# Empty DataFrame
# Columns: [name, market_value, app, conceded_goals, clean_sheets, yellow_card, second_yell, red_card, age, height, citizenship, position, foot, agent, club, joined, expire, last_contract, outfitter, sns, caps_goals]
# Index: []
#
# [0 rows x 21 columns]

# %%
league, order = "premier-league", "GB1"
base_url = f"https://www.transfermarkt.co.uk/{league}/startseite/wettbewerb/{order}"

headers = {'User-Agent': UserAgent().chrome}
response = requests.get(base_url, headers=headers)
dom = BeautifulSoup(response.content, "html.parser")

# 리그별 클럽의 링크데이터
elements = dom.select("#yw1 > table > tbody > tr")

base_link = "https://www.transfermarkt.co.uk"
links = []
for element in elements:
    link = element.select_one("a").get("href")
    link = urllib.parse.urljoin(base=base_link, url=link, allow_fragments=True)
    links.append(link)

for link in links:
    response = requests.get(link, headers=headers)
    dom = BeautifulSoup(response.content, "html.parser")
    
    # 리그의 선수 링크데이터
    elements = dom.select("#yw1 > table > tbody > tr")

    player_links = []
    for element in elements:
        player_link = element.select('a')[-1].get('href')
        player_link = urllib.parse.urljoin(base=base_link, url=player_link, allow_fragments=True)
        player_links.append(player_link)
            
        # 선수별 정보데이터
    for player_link in player_links:
        headers = {'User-Agent': UserAgent().chrome}
        response = requests.get(player_link, headers=headers)
        dom = BeautifulSoup(response.content, 'html.parser')

        name = dom.select_one('#main > div:nth-child(12) > div > div > div.dataMain > div > div.dataName > h1').text
        print(name)
        try:
            vals = dom.select('#main > div:nth-child(12) > div > div > div.dataContent > div > div:nth-child(3) > p.hide-for-small.notTablet > span.dataValue > a')
            caps_goals = int(vals[0].text) / int(vals[1].text)
        except:
            caps_goals = None
        try:
            market_value = dom.select_one('#main > div:nth-child(17) > div.large-8.columns > div:nth-child(2) > div.row.collapse > div.large-6.large-push-6.small-12.columns > div > div.box.viewport-tracking > div.row.collapse > div > div > div > div.row.collapse > div.large-5.columns.small-12 > div > div.zeile-oben > div.right-td > a:nth-child(1)').text
        except:
            market_value = None
        try:
            app = dom.find_all('span', 'wert')[0].text
            conceded_goals = dom.find_all('span', 'wert')[2].text
            clean_sheets = dom.find_all('span', 'wert')[4].text
            yellow_card = dom.find_all('span', 'wert')[1].text
            second_yell = dom.find_all('span', 'wert')[3].text
            red_card = dom.find_all('span', 'wert')[5].text
        except:
            app, conceded_goals, clean_sheets, yellow_card, second_yell, red_card = None, None, None, None, None, None

        for info in dom.find_all('tr')[:15]:
            if info.find('th') is None:
                continue

            if info.find('th').text.strip()[:-1] == "Age":
                age = info.find('td').text
            elif info.find('th').text[:-1] == "Height":
                height = info.find('td').text
            elif info.find('th').text[:-1] == "Citizenship":
                citizenship = len(np.unique(info.find('td').text))
            elif info.find('th').text[:-1] == "Position":
                position = info.find('td').text.replace(" ", "").replace("\n", "")
            elif info.find('th').text[:-1] == "Foot":
                foot = info.find('td').text
            elif info.find('th').text[:-1] == "Player agent":
                agent = info.find('td').text.replace("\n", "")
            elif info.find('th').text.strip()[:-1] == "Current club":
                club = info.find('td').text.strip()
            elif info.find('th').text.strip()[:-1] == "Joined":
                joined = info.find('td').text.strip()
            elif info.find('th').text.strip()[:-1] == "Contract expires":
                expire = info.find('td').text.strip()
            elif info.find('th').text.strip()[:-1] == "Date of last contract extension":
                last_contract = info.find('td').text.strip()
            elif info.find('th').text.strip()[:-1] == "Outfitter":
                outfitter = info.find('td').text.strip()
            elif info.find('th').text.strip()[:-1] == "Social-Media":
                sns = len(info.find_all('a'))

        data = {
            'name': name, 'market_value': market_value, 'caps_goals': caps_goals, 'app': app,
            'conceded_goals': conceded_goals,
            'clean_sheets': clean_sheets, 'yellow_card': yellow_card, 'second_yell': second_yell,
            'red_card': red_card, 'age': age, 'height': height, 'citizenship': citizenship,
            'position': position, 'foot': foot, 'agent': agent, 'club': club, 'joined': joined,
            'expire': expire, 'last_contract': last_contract, 'outfitter': outfitter, 'sns': sns
        }

        df.loc[len(df)] = data
        time.sleep(0.5)
# Out:
# Ederson
# Zack Steffen
# Scott Carson
# Rúben Dias
# Aymeric Laporte
# Nathan Aké
# John Stones
# Eric García
# Philippe Sandler
# Benjamin Mendy
# Oleksandr Zinchenko
# João Cancelo
# Kyle Walker
# Rodri
# Fernandinho
# Phil Foden
# Ilkay Gündogan
# Kevin De Bruyne
# Bernardo Silva
# Raheem Sterling
# Ferran Torres
# Riyad Mahrez
# Gabriel Jesus
# Sergio Agüero
# Alisson
# Caoimhin Kelleher
# Adrián
# Virgil van Dijk
# Joe Gomez
# Ozan Kabak
# Joel Matip
# Rhys Williams
# Nathaniel Phillips
# Ben Davies
# Andrew Robertson
# Konstantinos Tsimikas
# Trent Alexander-Arnold
# Neco Williams
# Fabinho
# Naby Keïta
# Georginio Wijnaldum
# Thiago
# Jordan Henderson
# Alex Oxlade-Chamberlain
# James Milner
# Curtis Jones
# Ben Woodburn
# Sadio Mané
# Diogo Jota
# Mohamed Salah
# Xherdan Shaqiri
# Roberto Firmino
# Divock Origi
# Edouard Mendy
# Kepa
# Willy Caballero
# Kurt Zouma
# Andreas Christensen
# Antonio Rüdiger
# Thiago Silva
# Ben Chilwell
# Emerson
# Marcos Alonso
# Reece James
# César Azpilicueta
# Jorginho
# N'Golo Kanté
# Mateo Kovacic
# Billy Gilmour
# Kai Havertz
# Mason Mount
# Charly Musonda Jr.
# Callum Hudson-Odoi
# Christian Pulisic
# Hakim Ziyech
# Timo Werner
# Tammy Abraham
# Olivier Giroud
# David de Gea
# Dean Henderson
# Sergio Romero
# Nathan Bishop
# Lee Grant
# Harry Maguire
# Victor Lindelöf
# Eric Bailly
# Axel Tuanzebe
# Phil Jones
# Alex Telles
# Luke Shaw
# Brandon Williams
# Aaron Wan-Bissaka
# Nemanja Matic
# Paul Pogba
# Donny van de Beek
# Scott McTominay
# Fred
# Ethan Galbraith
# Hannibal Mejbri
# Bruno Fernandes
# Juan Mata
# Marcus Rashford
# Daniel James
# Anthony Elanga
# Mason Greenwood
# Amad Diallo
# Anthony Martial
# Edinson Cavani
# Hugo Lloris
# Joe Hart
# Alfie Whiteman
# Davinson Sánchez
# Eric Dier
# Toby Alderweireld
# Joe Rodon
# Japhet Tanganga
# Sergio Reguilón
# Ben Davies
# Danny Rose
# Serge Aurier
# Matt Doherty
# Harry Winks
# Tanguy Ndombélé
# Pierre-Emile Höjbjerg
# Giovani Lo Celso
# Moussa Sissoko
# Dele Alli
# Heung-min Son
# Steven Bergwijn
# Lucas Moura
# Gareth Bale
# Erik Lamela
# Harry Kane
# Carlos Vinícius
# Bernd Leno
# Mathew Ryan
# Rúnar Alex Rúnarsson
# Dejan Iliev
# Gabriel
# Rob Holding
# Calum Chambers
# Pablo Marí
# David Luiz
# Kieran Tierney
# Héctor Bellerín
# Cédric Soares
# Thomas Partey
# Granit Xhaka
# Mohamed Elneny
# Dani Ceballos
# Martin Ødegaard
# Emile Smith Rowe
# Gabriel Martinelli
# Bukayo Saka
# Nicolas Pépé
# Willian
# Reiss Nelson
# Alexandre Lacazette
# Pierre-Emerick Aubameyang
# Eddie Nketiah
# Kasper Schmeichel
# Danny Ward
# Eldin Jakupovic
# Caglar Söyüncü
# Wesley Fofana
# Jonny Evans
# Wes Morgan
# Luke Thomas
# Christian Fuchs
# Ricardo Pereira
# Timothy Castagne
# James Justin
# Wilfred Ndidi
# Hamza Choudhury
# Nampalys Mendy
# Daniel Amartey
# Youri Tielemans
# Dennis Praet
# Marc Albrighton
# Harvey Barnes
# James Maddison
# Cengiz Ünder
# Ayoze Pérez
# Kelechi Iheanacho
# Jamie Vardy
# Jordan Pickford
# Robin Olsen
# João Virgínia
# Michael Keane
# Ben Godfrey
# Yerry Mina
# Mason Holgate
# Lucas Digne
# Niels Nkounkou
# Seamus Coleman
# Jean-Philippe Gbamin
# Muhamed Besic
# Abdoulaye Doucouré
# Allan
# André Gomes
# Tom Davies
# Fabian Delph
# James Rodríguez
# Gylfi Sigurdsson
# Richarlison
# Alex Iwobi
# Bernard
# Joshua King
# Dominic Calvert-Lewin
# Rui Patrício
# John Ruddy
# Andreas Söndergaard
# Conor Coady
# Willy Boly
# Romain Saïss
# Max Kilman
# Rayan Aït Nouri
# Jonny Otto
# Marçal
# Nélson Semedo
# Ki-Jana Hoever
# Rúben Neves
# Leander Dendoncker
# Owen Otasowie
# Morgan Gibbs-White
# Vitinha
# João Moutinho
# Pedro Neto
# Adama Traoré
# Daniel Podence
# Raúl Jiménez
# Fábio Silva
# Willian José
# Renat Dadashov
# Emiliano Martínez
# Tom Heaton
# Jed Steer
# Tyrone Mings
# Ezri Konsa
# Kortney Hause
# Björn Engels
# Matt Targett
# Neil Taylor
# Matty Cash
# Ahmed Elmohamady
# Douglas Luiz
# Marvelous Nakamba
# John McGinn
# Ross Barkley
# Morgan Sanson
# Jacob Ramsey
# Jack Grealish
# Trezeguet
# Bertrand Traoré
# Anwar El Ghazi
# Ollie Watkins
# Wesley
# Keinan Davis
# Lukasz Fabianski
# Darren Randolph
# David Martin
# Issa Diop
# Fabián Balbuena
# Craig Dawson
# Angelo Ogbonna
# Frederik Alves
# Arthur Masuaku
# Aaron Cresswell
# Vladimir Coufal
# Ryan Fredericks
# Ben Johnson
# Declan Rice
# Tomas Soucek
# Mark Noble
# Pablo Fornals
# Jesse Lingard
# Manuel Lanzini
# Saïd Benrahma
# Jarrod Bowen
# Andriy Yarmolenko
# Michail Antonio
# Martin Dubravka
# Karl Darlow
# Mark Gillespie
# Jamaal Lascelles
# Fabian Schär
# Ciaran Clark
# Federico Fernández
# Jamal Lewis
# Paul Dummett
# Matt Ritchie
# Emil Krafth
# Javier Manquillo
# Isaac Hayden
# Joe Willock
# Sean Longstaff
# Jonjo Shelvey
# Jeff Hendrick
# Matthew Longstaff
# Miguel Almirón
# Henri Saivet
# Allan Saint-Maximin
# Ryan Fraser
# Christian Atsu
# Jacob Murphy
# Callum Wilson
# Joelinton
# Dwight Gayle
# Andy Carroll
# Alex McCarthy
# Fraser Forster
# Harry Lewis
# Jan Bednarek
# Jannik Vestergaard
# Mohammed Salisu
# Jack Stephens
# Ryan Bertrand
# Sam McQueen
# Kyle Walker-Peters
# Ibrahima Diallo
# Oriol Romeu
# James Ward-Prowse
# Stuart Armstrong
# Will Smallbone
# Nathan Redmond
# Moussa Djenepo
# Takumi Minamino
# Theo Walcott
# Nathan Tella
# Danny Ings
# Che Adams
# Michael Obafemi
# Dan N'Lundulu
# Robert Sánchez
# Jason Steele
# Christian Walton
# Ben White
# Lewis Dunk
# Adam Webster
# Dan Burn
# Joël Veltman
# Michal Karbownik
# Tariq Lamptey
# Yves Bissouma
# Jakub Moder
# Davy Pröpper
# Pascal Groß
# Steven Alzate
# Moisés Caicedo
# Solly March
# Alexis Mac Allister
# Adam Lallana
# Percy Tau
# Leandro Trossard
# José Izquierdo
# Alireza Jahanbakhsh
# Neal Maupay
# Aaron Connolly
# Danny Welbeck
# Florin Andone
# Andi Zeqiri
# Alphonse Areola
# Marek Rodak
# Fabri
# Joachim Andersen
# Tosin Adarabioyo
# Alfie Mawson
# Michael Hector
# Terence Kongolo
# Tim Ream
# Antonee Robinson
# Joe Bryan
# Ola Aina
# Kenny Tete
# Denis Odoi
# André Zambo Anguissa
# Mario Lemina
# Kevin McDonald
# Ruben Loftus-Cheek
# Harrison Reed
# Tom Cairney
# Bobby Reid
# Josh Onomah
# Ademola Lookman
# Ivan Cavaleiro
# Aleksandar Mitrovic
# Josh Maja
# Illan Meslier
# Kiko Casilla
# Elia Caprile
# Diego Llorente
# Robin Koch
# Liam Cooper
# Pascal Struijk
# Ezgjan Alioski
# Stuart Dallas
# Leif Davis
# Luke Ayling
# Gaetano Berardi
# Kalvin Phillips
# Ouasim Bouy
# Mateusz Klich
# Adam Forshaw
# Jamie Shackleton
# Pablo Hernández
# Jack Harrison
# Raphinha
# Hélder Costa
# Ian Poveda
# Tyler Roberts
# Rodrigo
# Patrick Bamford
# Joe Gelhardt
# Jack Butland
# Vicente Guaita
# Wayne Hennessey
# Stephen Henderson
# Cheikhou Kouyaté
# Mamadou Sakho
# Nathan Ferguson
# James Tomkins
# Gary Cahill
# Scott Dann
# Patrick van Aanholt
# Tyrick Mitchell
# Nathaniel Clyne
# Joel Ward
# Martin Kelly
# Luka Milivojevic
# Jairo Riedewald
# James McCarthy
# James McArthur
# Jeffrey Schlupp
# Eberechi Eze
# Wilfried Zaha
# Andros Townsend
# Jean-Philippe Mateta
# Michy Batshuayi
# Christian Benteke
# Jordan Ayew
# Connor Wickham
# Aaron Ramsdale
# Wes Foderingham
# Simon Moore
# Ethan Ampadu
# John Egan
# Jack O'Connell
# Chris Basham
# Kean Bryan
# Phil Jagielka
# Enda Stevens
# Max Lowe
# Jack Robinson
# Jayden Bogle
# George Baldock
# Sander Berge
# Jack Rodwell
# John Lundstram
# Oliver Norwood
# John Fleck
# Ben Osborn
# Oliver McBurnie
# Rhian Brewster
# Lys Mousset
# Oliver Burke
# David McGoldrick
# Billy Sharp
# Nick Pope
# Bailey Peacock-Farrell
# Will Norris
# James Tarkowski
# Ben Mee
# Kevin Long
# Jimmy Dunne
# Richard Nartey
# Charlie Taylor
# Erik Pieters
# Matthew Lowton
# Phil Bardsley
# Jack Cork
# Ashley Westwood
# Josh Brownhill
# Dale Stephens
# Robbie Brady
# Dwight McNeil
# Jóhann Berg Gudmundsson
# Chris Wood
# Ashley Barnes
# Jay Rodríguez
# Matej Vydra
# Sam Johnstone
# David Button
# Andy Lonergan
# Semi Ajayi
# Dara O'Shea
# Kyle Bartley
# Branislav Ivanovic
# Kieran Gibbs
# Conor Townsend
# Darnell Furlong
# Lee Peltier
# Okay Yokuslu
# Jake Livermore
# Conor Gallagher
# Romaine Sawyers
# Ainsley Maitland-Niles
# Kyle Edwards
# Grady Diangana
# Kamil Grosicki
# Matheus Pereira
# Matt Phillips
# Robert Snodgrass
# Karlan Grant
# Callum Robinson
# Mbaye Diagne
# Hal Robson-Kanu

# %%
df.tail(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e7e68462b21> in <module>
# ----> 1 df.tail(2)
#
# NameError: name 'df' is not defined

# %%
with open('datas/premier_players.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('datas/premier_players.pkl', 'rb') as f:
    datas = pickle.load(f)

# %%
datas.head()
# Out:
#               name market_value app conceded_goals clean_sheets yellow_card  \
# 0          Ederson      £50.40m  32             23           17           3
# 1     Zack Steffen       £5.40m   1              1            -           -
# 2     Scott Carson      £450Th.   -              -            -           -
# 3       Rúben Dias      £63.00m  29              1            -           3
# 4  Aymeric Laporte      £45.00m  14              -            -           1
#
#   second_yell red_card age  height  ...              position   foot  \
# 0           -        -  27  1,88 m  ...            Goalkeeper   left
# 1           -        -  26  1,91 m  ...            Goalkeeper  right
# 2           -        -  35  1,88 m  ...            Goalkeeper  right
# 3           -        -  23  1,87 m  ...  Defender-Centre-Back  right
# 4           -        -  26  1,89 m  ...  Defender-Centre-Back   left
#
#         agent             club        joined        expire last_contract  \
# 0  Gestifute   Manchester City   Jul 1, 2017  Jun 30, 2025  May 13, 2018
# 1  Wasserman   Manchester City   Jul 9, 2019  Jun 30, 2023  May 13, 2018
# 2  Wasserman   Manchester City   Aug 8, 2019  May 31, 2021  Aug 19, 2020
# 3  Gestifute   Manchester City  Sep 29, 2020  Jun 30, 2026  Aug 19, 2020
# 4  Wasserman   Manchester City  Jan 30, 2018  Jun 30, 2025  Feb 22, 2019
#
#   outfitter sns caps_goals
# 0      Puma   3        NaN
# 1      Nike   2        NaN
# 2      Nike   2        NaN
# 3      Nike   2       13.5
# 4    adidas   3       None
#
# [5 rows x 21 columns]

# %%
datas.replace({'-': '0'}, inplace=True)
datas["market_value"] = datas["market_value"].apply(lambda x: str(x)[1:])
# datas.replace({None: '0'}, inplace=True)

# %%
datas[datas['market_value'] == 'one']
# Out:
#                     name market_value   app conceded_goals clean_sheets  \
# 98       Hannibal Mejbri          one    18              3            8
# 103       Anthony Elanga          one    15              7            2
# 211  Andreas Söndergaard          one    16             21            7
# 317          Sam McQueen          one  None           None         None
# 400          Ouasim Bouy          one  None           None         None
# 443          Simon Moore          one  None           None         None
#
#     yellow_card second_yell red_card age  height  ...  \
# 98            5           0        1  18  1,82 m  ...
# 103           0           0        0  19  1,78 m  ...
# 211           0           0        0  20  1,88 m  ...
# 317        None        None     None  26  1,81 m  ...
# 400        None        None     None  27  1,81 m  ...
# 443        None        None     None  30  1,91 m  ...
#
#                        position   foot                   agent  \
# 98     midfield-CentralMidfield  right     Fabio Mello Sports
# 103           attack-LeftWinger  right     ICM Stellar Sports
# 211                  Goalkeeper  right  New Era Global Sports
# 317          Defender-Left-Back   left             New Vision
# 400  midfield-DefensiveMidfield   left            Mino Raiola
# 443                  Goalkeeper  right              Wasserman
#
#                             club        joined        expire last_contract  \
# 98         Manchester United U23   Jul 1, 2020  Jun 30, 2026  Mar 16, 2021
# 103        Manchester United U23   Jul 1, 2020             0  Mar 16, 2021
# 211  Wolverhampton Wanderers U23  Jan 26, 2018  Jun 30, 2023  Dec 17, 2020
# 317               Southampton FC   Jul 1, 2016  Jun 30, 2021   Dec 5, 2016
# 400                 Leeds United   Aug 1, 2017  Jun 30, 2021   Sep 9, 2019
# 443             Sheffield United  Aug 19, 2016  Jun 30, 2021  Jul 26, 2018
#
#     outfitter sns  caps_goals
# 98     adidas   1         1.5
# 103      Nike   2         2.5
# 211      Puma   1         NaN
# 317      Nike   2         NaN
# 400      Nike   1         6.0
# 443      Nike   1         NaN
#
# [6 rows x 21 columns]

# %%
datas.loc[98, 'market_value'] = '9.00m' # market_value가 없어 19/20 fee로 대체
datas.loc[103, 'market_value'] = None # market_value, fee 존재 x
datas.loc[211, 'market_value'] = None # market_value, fee 존재 x
datas.loc[317, 'market_value'] = '720Th.' # 왜 못갖고온지 모르겠음
datas.loc[400, 'market_value'] = '270Th.' # 왜 못갖고온지 모르겠음
datas.loc[443, 'market_value'] = '360Th.' # 왜 못갖고온지 모르겠음

# %%
datas[datas['market_value'] == 'one']
# Out:
# Empty DataFrame
# Columns: [name, market_value, app, conceded_goals, clean_sheets, yellow_card, second_yell, red_card, age, height, citizenship, position, foot, agent, club, joined, expire, last_contract, outfitter, sns, caps_goals]
# Index: []
#
# [0 rows x 21 columns]

# %%
datas['name'] = datas['name'].apply(lambda x: x.strip().replace(" ", "").replace("-", ""))

# %%
print(datas.shape)
datas.tail()
# Out:
# (516, 21)
#                 name market_value app conceded_goals clean_sheets yellow_card  \
# 511  RobertSnodgrass        1.80m  11              0            0           2
# 512      KarlanGrant        8.10m  18              1            0           1
# 513   CallumRobinson        5.40m  25              5            0           0
# 514      MbayeDiagne        2.70m  13              2            2           2
# 515    HalRobsonKanu        1.62m  15              0            0           1
#
#     second_yell red_card age  height  ...               position   foot  \
# 511           0        0  33  1,82 m  ...     attack-RightWinger   left
# 512           0        0  23  1,83 m  ...  attack-Centre-Forward  right
# 513           0        0  26  1,78 m  ...  attack-Centre-Forward  right
# 514           0        0  29  1,91 m  ...  attack-Centre-Forward  right
# 515           0        0  31  1,83 m  ...  attack-Centre-Forward   left
#
#                       agent                  club        joined        expire  \
# 511  SMI Sports Management   West Bromwich Albion   Jan 8, 2021  Jun 30, 2022
# 512     ICM Stellar Sports   West Bromwich Albion  Oct 15, 2020  Jun 30, 2026
# 513              Wasserman   West Bromwich Albion   Sep 9, 2020  Jun 30, 2025
# 514              GOAL CLUB   West Bromwich Albion  Jan 29, 2021  Jun 30, 2021
# 515               no agent   West Bromwich Albion  Aug 31, 2016  Jun 30, 2021
#
#     last_contract outfitter sns  caps_goals
# 511  Aug 31, 2019      Nike   2         4.0
# 512  Aug 31, 2019    adidas   2         NaN
# 513  Aug 31, 2019    adidas   2        17.0
# 514  Aug 31, 2019    adidas   1         NaN
# 515   Jul 6, 2017    adidas   2         9.2
#
# [5 rows x 21 columns]

# %%
def converter(value):
    if value == None:
        m_value = np.NaN
    elif value[-1] == "m":
        m_value = int(value.replace('m', '0000').replace('.', ''))
    elif value[-3:] == "Th.":
        m_value = int(value.replace('Th.', '000').replace('.', ''))
    return m_value

# %%
datas['market_value'] = datas['market_value'].apply(converter)

# %%
datas.tail()
# Out:
#                 name  market_value app conceded_goals clean_sheets  \
# 511  RobertSnodgrass     1800000.0  11              0            0
# 512      KarlanGrant     8100000.0  18              1            0
# 513   CallumRobinson     5400000.0  25              5            0
# 514      MbayeDiagne     2700000.0  13              2            2
# 515    HalRobsonKanu     1620000.0  15              0            0
#
#     yellow_card second_yell red_card age  height  ...               position  \
# 511           2           0        0  33  1,82 m  ...     attack-RightWinger
# 512           1           0        0  23  1,83 m  ...  attack-Centre-Forward
# 513           0           0        0  26  1,78 m  ...  attack-Centre-Forward
# 514           2           0        0  29  1,91 m  ...  attack-Centre-Forward
# 515           1           0        0  31  1,83 m  ...  attack-Centre-Forward
#
#       foot                   agent                  club        joined  \
# 511   left  SMI Sports Management   West Bromwich Albion   Jan 8, 2021
# 512  right     ICM Stellar Sports   West Bromwich Albion  Oct 15, 2020
# 513  right              Wasserman   West Bromwich Albion   Sep 9, 2020
# 514  right              GOAL CLUB   West Bromwich Albion  Jan 29, 2021
# 515   left               no agent   West Bromwich Albion  Aug 31, 2016
#
#            expire last_contract outfitter sns  caps_goals
# 511  Jun 30, 2022  Aug 31, 2019      Nike   2         4.0
# 512  Jun 30, 2026  Aug 31, 2019    adidas   2         NaN
# 513  Jun 30, 2025  Aug 31, 2019    adidas   2        17.0
# 514  Jun 30, 2021  Aug 31, 2019    adidas   1         NaN
# 515  Jun 30, 2021   Jul 6, 2017    adidas   2         9.2
#
# [5 rows x 21 columns]

# %%
datas['height'] = datas['height'].apply(lambda x: x.replace('m', '').replace(',', '').strip())
datas.tail(3)
# Out:
#                name  market_value app conceded_goals clean_sheets yellow_card  \
# 513  CallumRobinson     5400000.0  25              5            0           0
# 514     MbayeDiagne     2700000.0  13              2            2           2
# 515   HalRobsonKanu     1620000.0  15              0            0           1
#
#     second_yell red_card age height  ...               position   foot  \
# 513           0        0  26    178  ...  attack-Centre-Forward  right
# 514           0        0  29    191  ...  attack-Centre-Forward  right
# 515           0        0  31    183  ...  attack-Centre-Forward   left
#
#           agent                  club        joined        expire  \
# 513  Wasserman   West Bromwich Albion   Sep 9, 2020  Jun 30, 2025
# 514  GOAL CLUB   West Bromwich Albion  Jan 29, 2021  Jun 30, 2021
# 515   no agent   West Bromwich Albion  Aug 31, 2016  Jun 30, 2021
#
#     last_contract outfitter sns  caps_goals
# 513  Aug 31, 2019    adidas   2        17.0
# 514  Aug 31, 2019    adidas   1         NaN
# 515   Jul 6, 2017    adidas   2         9.2
#
# [3 rows x 21 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
datas.tail()
# Out:
#                 name  market_value app conceded_goals clean_sheets  \
# 511  RobertSnodgrass     1800000.0  11              0            0
# 512      KarlanGrant     8100000.0  18              1            0
# 513   CallumRobinson     5400000.0  25              5            0
# 514      MbayeDiagne     2700000.0  13              2            2
# 515    HalRobsonKanu     1620000.0  15              0            0
#
#     yellow_card second_yell red_card age height  citizenship  \
# 511           2           0        0  33    182            1
# 512           1           0        0  23    183            1
# 513           0           0        0  26    178            1
# 514           2           0        0  29    191            1
# 515           1           0        0  31    183            1
#
#                   position   foot                   agent  \
# 511     attack-RightWinger   left  SMI Sports Management
# 512  attack-Centre-Forward  right     ICM Stellar Sports
# 513  attack-Centre-Forward  right              Wasserman
# 514  attack-Centre-Forward  right              GOAL CLUB
# 515  attack-Centre-Forward   left               no agent
#
#                      club        joined        expire last_contract outfitter  \
# 511  West Bromwich Albion   Jan 8, 2021  Jun 30, 2022  Aug 31, 2019      Nike
# 512  West Bromwich Albion  Oct 15, 2020  Jun 30, 2026  Aug 31, 2019    adidas
# 513  West Bromwich Albion   Sep 9, 2020  Jun 30, 2025  Aug 31, 2019    adidas
# 514  West Bromwich Albion  Jan 29, 2021  Jun 30, 2021  Aug 31, 2019    adidas
# 515  West Bromwich Albion  Aug 31, 2016  Jun 30, 2021   Jul 6, 2017    adidas
#
#      sns  caps_goals
# 511    2         4.0
# 512    2         NaN
# 513    2        17.0
# 514    1         NaN
# 515    2         9.2

# %%
print(len(np.unique(datas['position'])))
np.unique(datas['position'])
# Out:
# 13
# array(['Defender-Centre-Back', 'Defender-Left-Back',
#        'Defender-Right-Back', 'Goalkeeper', 'attack-Centre-Forward',
#        'attack-LeftWinger', 'attack-RightWinger', 'attack-SecondStriker',
#        'midfield-AttackingMidfield', 'midfield-CentralMidfield',
#        'midfield-DefensiveMidfield', 'midfield-LeftMidfield',
#        'midfield-RightMidfield'], dtype=object)

# %%
datas['market_value'] = datas['market_value'].astype('float')
# datas['app'] = datas['app'].astype('int')

# %%
# 어떻게 처리할지
datas[datas['app'].isnull()]
# Out:
#                  name  market_value   app conceded_goals clean_sheets  \
# 71   CharlyMusondaJr.      900000.0  None           None         None
# 80       SergioRomero     1350000.0  None           None         None
# 87          PhilJones     4500000.0  None           None         None
# 196      MuhamedBesic     1800000.0  None           None         None
# 233     RenatDadashov      270000.0  None           None         None
# 317        SamMcQueen      720000.0  None           None         None
# 400        OuasimBouy      270000.0  None           None         None
# 419    NathanFerguson     3600000.0  None           None         None
# 443        SimonMoore      360000.0  None           None         None
#
#     yellow_card second_yell red_card age height  citizenship  \
# 71         None        None     None  24    173            1
# 80         None        None     None  34    192            1
# 87         None        None     None  29    185            1
# 196        None        None     None  28    180            1
# 233        None        None     None  21    186            1
# 317        None        None     None  26    181            1
# 400        None        None     None  27    181            1
# 419        None        None     None  20    184            1
# 443        None        None     None  30    191            1
#
#                        position   foot  \
# 71   midfield-AttackingMidfield  right
# 80                   Goalkeeper  right
# 87         Defender-Centre-Back  right
# 196  midfield-DefensiveMidfield  right
# 233       attack-Centre-Forward  right
# 317          Defender-Left-Back   left
# 400  midfield-DefensiveMidfield   left
# 419        Defender-Centre-Back  right
# 443                  Goalkeeper  right
#
#                                       agent                     club  \
# 71                      ICM Stellar Sports                Chelsea FC
# 80                      ICM Stellar Sports         Manchester United
# 87                               Wasserman         Manchester United
# 196                               no agent                Everton FC
# 233                 Universal Sports Group   Wolverhampton Wanderers
# 317                             New Vision            Southampton FC
# 400                            Mino Raiola              Leeds United
# 419  Sport Avenir Management International            Crystal Palace
# 443                              Wasserman          Sheffield United
#
#            joined        expire last_contract outfitter  sns  caps_goals
# 71    Jul 1, 2017  Jun 30, 2022   Dec 8, 2017      Nike    1        12.0
# 80   Jul 27, 2015  Jun 30, 2021  Jul 16, 2017    adidas    2         NaN
# 87    Jul 1, 2011  Jun 30, 2023   Feb 8, 2019    adidas    1         NaN
# 196  Jul 28, 2014  Jun 30, 2021  Feb 29, 2016      Nike    3         NaN
# 233   Aug 6, 2019  Jun 30, 2023   Oct 3, 2020      Nike    1         NaN
# 317   Jul 1, 2016  Jun 30, 2021   Dec 5, 2016      Nike    2         NaN
# 400   Aug 1, 2017  Jun 30, 2021   Sep 9, 2019      Nike    1         6.0
# 419  Jul 27, 2020  Jun 30, 2023  Aug 21, 2020      Puma    1         NaN
# 443  Aug 19, 2016  Jun 30, 2021  Jul 26, 2018      Nike    1         NaN

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 515
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            516 non-null    object
#  1   market_value    514 non-null    float64
#  2   app             507 non-null    object
#  3   conceded_goals  507 non-null    object
#  4   clean_sheets    507 non-null    object
#  5   yellow_card     507 non-null    object
#  6   second_yell     507 non-null    object
#  7   red_card        507 non-null    object
#  8   age             516 non-null    object
#  9   height          516 non-null    object
#  10  citizenship     516 non-null    int64
#  11  position        516 non-null    object
#  12  foot            516 non-null    object
#  13  agent           516 non-null    object
#  14  club            516 non-null    object
#  15  joined          516 non-null    object
#  16  expire          516 non-null    object
#  17  last_contract   516 non-null    object
#  18  outfitter       516 non-null    object
#  19  sns             516 non-null    int64
#  20  caps_goals      230 non-null    float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 104.9+ KB

# %%
msno.bar(datas);

# %%
with open('datas/premier_total.pkl', 'rb') as f:
    datas2 = pickle.load(f)

# %%
datas2['name'] = datas2['name'].apply(lambda x: x.strip())

# %%
datas['name'] = datas['name'].apply(lambda x: x.replace(" ", "").replace("-", ""))
datas2['name'] = datas['name'].apply(lambda x: x.replace(" ", "").replace("-", ""))

# %%
dfs = pd.merge(datas, datas2, on='name')

# %%
dfs
# Out:
#                 name  market_value app conceded_goals clean_sheets  \
# 0            Ederson    50400000.0  32             23           17
# 1        ZackSteffen     5400000.0   1              1            0
# 2        ScottCarson      450000.0   0              0            0
# 3          RúbenDias    63000000.0  29              1            0
# 4     AymericLaporte    45000000.0  14              0            0
# ..               ...           ...  ..            ...          ...
# 513  RobertSnodgrass     1800000.0  11              0            0
# 514      KarlanGrant     8100000.0  18              1            0
# 515   CallumRobinson     5400000.0  25              5            0
# 516      MbayeDiagne     2700000.0  13              2            2
# 517    HalRobsonKanu     1620000.0  15              0            0
#
#     yellow_card second_yell red_card age height  citizenship  \
# 0             3           0        0  27    188            1
# 1             0           0        0  26    191            1
# 2             0           0        0  35    188            1
# 3             3           0        0  23    187            1
# 4             1           0        0  26    189            1
# ..          ...         ...      ...  ..    ...          ...
# 513           2           0        0  33    182            1
# 514           1           0        0  23    183            1
# 515           0           0        0  26    178            1
# 516           2           0        0  29    191            1
# 517           1           0        0  31    183            1
#
#                   position   foot                   agent  \
# 0               Goalkeeper   left              Gestifute
# 1               Goalkeeper  right              Wasserman
# 2               Goalkeeper  right              Wasserman
# 3     Defender-Centre-Back  right              Gestifute
# 4     Defender-Centre-Back   left              Wasserman
# ..                     ...    ...                     ...
# 513     attack-RightWinger   left  SMI Sports Management
# 514  attack-Centre-Forward  right     ICM Stellar Sports
# 515  attack-Centre-Forward  right              Wasserman
# 516  attack-Centre-Forward  right              GOAL CLUB
# 517  attack-Centre-Forward   left               no agent
#
#                      club        joined        expire last_contract outfitter  \
# 0         Manchester City   Jul 1, 2017  Jun 30, 2025  May 13, 2018      Puma
# 1         Manchester City   Jul 9, 2019  Jun 30, 2023  May 13, 2018      Nike
# 2         Manchester City   Aug 8, 2019  May 31, 2021  Aug 19, 2020      Nike
# 3         Manchester City  Sep 29, 2020  Jun 30, 2026  Aug 19, 2020      Nike
# 4         Manchester City  Jan 30, 2018  Jun 30, 2025  Feb 22, 2019    adidas
# ..                    ...           ...           ...           ...       ...
# 513  West Bromwich Albion   Jan 8, 2021  Jun 30, 2022  Aug 31, 2019      Nike
# 514  West Bromwich Albion  Oct 15, 2020  Jun 30, 2026  Aug 31, 2019    adidas
# 515  West Bromwich Albion   Sep 9, 2020  Jun 30, 2025  Aug 31, 2019    adidas
# 516  West Bromwich Albion  Jan 29, 2021  Jun 30, 2021  Aug 31, 2019    adidas
# 517  West Bromwich Albion  Aug 31, 2016  Jun 30, 2021   Jul 6, 2017    adidas
#
#      sns  caps_goals   Apps  Mins Tackles Inter Fouls Offsides Clear Drbed  \
# 0      3         NaN     30  2637     0.7   0.3   0.9        0   1.2   0.5
# 1      2         NaN     22  1977     1.2   0.5   1.7        0   0.1   0.4
# 2      2         NaN  22(2)  1911     1.4   0.4   1.0        0   0.3   1.3
# 3      2        13.5      4   360     0.8   1.3   0.5      0.5   6.5   0.3
# 4      3         NaN     11   976     0.7   0.4   1.5        0     0   0.5
# ..   ...         ...    ...   ...     ...   ...   ...      ...   ...   ...
# 513    2         4.0   0(1)     9       0     0     0        0     0     1
# 514    2         NaN   1(1)     3       1     0   0.5        0     0     0
# 515    2        17.0      1    90       0     0     0        0     0     0
# 516    1         NaN      1    90       0     0     0        0     0     0
# 517    2         9.2      1    90       5     0     1        1     3     0
#
#     Blocks OwnG  Rating_x     Position         Team  Age Assists KeyP  AvgP  \
# 0      0.3    0      7.81     AM(C),FW    Tottenham   27      13  1.4  26.0
# 1      0.1    0      7.73       AM(CL)        Villa   25      10  3.4  40.9
# 2        0    0      7.56    M(CLR),FW         City   29      11    3  50.3
# 3        0    0      7.53        D(CL)        Villa   25       0    0  35.3
# 4        0    0      7.46   AM(CLR),FW          Ham   28       3  0.9  36.2
# ..     ...  ...       ...          ...          ...  ...     ...  ...   ...
# 513      0    0      5.74     AM(C),FW      Man Utd   31       0    0   2.0
# 514      0    0      5.68   Midfielder  Southampton   19       0    0   1.5
# 515      0    0      5.65           GK       Fulham   24       0    0  25.0
# 516      0    0      5.41           GK      Chelsea   39       0    0  24.0
# 517      0    0      5.06     Defender  Southampton   20       0    0  19.0
#
#       PS% Crosses LongB ThrB  Rating_y Goals  SpG  Drb Fouled  Off Disp UnsTch
# 0    69.5     0.2   1.9  0.1      7.81    21  3.9  1.3    1.8  0.3  1.6    1.9
# 1    83.2     0.7   1.3  0.1      7.73     6  2.1  2.8    4.5  0.3  1.5    2.1
# 2    81.7     1.5   2.5  0.2      7.56     5  3.3  1.8    1.3    0  1.3    1.8
# 3    75.2       0   1.0    0      7.53     1  0.8    0    0.3    0    0    0.3
# 4    80.7     0.4   0.9    0      7.46     9  3.0  1.3    1.6  0.4  1.3    1.7
# ..    ...     ...   ...  ...       ...   ...  ...  ...    ...  ...  ...    ...
# 513   100       0     0    0      5.74     0    0    0      0    0    2      1
# 514  66.7       0     0    0      5.68     0    0    0    0.5    0    0    0.5
# 515    76       0     8    0      5.65     0    0    0      0    0    0      0
# 516  91.7       0     2    0      5.41     0    0    0      0    0    0      0
# 517  78.9       0     0    0      5.06     0    0    0      0    0    0      0
#
# [518 rows x 50 columns]

# %%
with open('datas/final_total_df.pkl', 'wb') as f:
    pickle.dump(final_dfs, f)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
with open('datas/final_total_df.pkl', 'rb') as f:
    premier_df = pickle.load(f)

# %%
premier_df.tail()
# Out:
#                 name  market_value app conceded_goals clean_sheets  \
# 513  RobertSnodgrass     1800000.0  11              0            0
# 514      KarlanGrant     8100000.0  18              1            0
# 515   CallumRobinson     5400000.0  25              5            0
# 516      MbayeDiagne     2700000.0  13              2            2
# 517    HalRobsonKanu     1620000.0  15              0            0
#
#     yellow_card second_yell red_card age height  citizenship  \
# 513           2           0        0  33    182            1
# 514           1           0        0  23    183            1
# 515           0           0        0  26    178            1
# 516           2           0        0  29    191            1
# 517           1           0        0  31    183            1
#
#                   position   foot                   agent  \
# 513     attack-RightWinger   left  SMI Sports Management
# 514  attack-Centre-Forward  right     ICM Stellar Sports
# 515  attack-Centre-Forward  right              Wasserman
# 516  attack-Centre-Forward  right              GOAL CLUB
# 517  attack-Centre-Forward   left               no agent
#
#                      club        joined        expire last_contract outfitter  \
# 513  West Bromwich Albion   Jan 8, 2021  Jun 30, 2022  Aug 31, 2019      Nike
# 514  West Bromwich Albion  Oct 15, 2020  Jun 30, 2026  Aug 31, 2019    adidas
# 515  West Bromwich Albion   Sep 9, 2020  Jun 30, 2025  Aug 31, 2019    adidas
# 516  West Bromwich Albion  Jan 29, 2021  Jun 30, 2021  Aug 31, 2019    adidas
# 517  West Bromwich Albion  Aug 31, 2016  Jun 30, 2021   Jul 6, 2017    adidas
#
#      sns  caps_goals  Apps  Mins Tackles Inter Fouls Offsides Clear Drbed  \
# 513    2         4.0  0(1)     9       0     0     0        0     0     1
# 514    2         NaN  1(1)     3       1     0   0.5        0     0     0
# 515    2        17.0     1    90       0     0     0        0     0     0
# 516    1         NaN     1    90       0     0     0        0     0     0
# 517    2         9.2     1    90       5     0     1        1     3     0
#
#     Blocks OwnG  Rating_x     Position         Team  Age Assists KeyP  AvgP  \
# 513      0    0      5.74     AM(C),FW      Man Utd   31       0    0   2.0
# 514      0    0      5.68   Midfielder  Southampton   19       0    0   1.5
# 515      0    0      5.65           GK       Fulham   24       0    0  25.0
# 516      0    0      5.41           GK      Chelsea   39       0    0  24.0
# 517      0    0      5.06     Defender  Southampton   20       0    0  19.0
#
#       PS% Crosses LongB ThrB  Rating_y Goals SpG Drb Fouled Off Disp UnsTch
# 513   100       0     0    0      5.74     0   0   0      0   0    2      1
# 514  66.7       0     0    0      5.68     0   0   0    0.5   0    0    0.5
# 515    76       0     8    0      5.65     0   0   0      0   0    0      0
# 516  91.7       0     2    0      5.41     0   0   0      0   0    0      0
# 517  78.9       0     0    0      5.06     0   0   0      0   0    0      0

# %%
mon_datas = {"Jan": "1", "Feb": "2", "Mar": "3", "Apr": "4", "May": "5", "Jun": "6",
            "Jul": "7", "Aug": "8", "Sep": "9", "Oct": "10", "Nov": "11", "Dec": "12"}

def converter_date(date):
    try:
        mon, year = date.split(",")
        year = year.strip()
        mon, day = mon.split(" ")
        for key, value in mon_datas.items():
            mon = mon.replace(key, str(value))
            
        result = year + "-" + mon + "-" + day
    except:
        result = None
    
    return result

# %%
premier_df['joined'] = premier_df['joined'].apply(converter_date)
premier_df['last_contract'] = premier_df['last_contract'].apply(converter_date)
premier_df['expire'] = premier_df['expire'].apply(converter_date)

# %%
premier_df.tail()
# Out:
#                 name  market_value app conceded_goals clean_sheets  \
# 513  RobertSnodgrass     1800000.0  11              0            0
# 514      KarlanGrant     8100000.0  18              1            0
# 515   CallumRobinson     5400000.0  25              5            0
# 516      MbayeDiagne     2700000.0  13              2            2
# 517    HalRobsonKanu     1620000.0  15              0            0
#
#     yellow_card second_yell red_card age height  citizenship  \
# 513           2           0        0  33    182            1
# 514           1           0        0  23    183            1
# 515           0           0        0  26    178            1
# 516           2           0        0  29    191            1
# 517           1           0        0  31    183            1
#
#                   position   foot                   agent  \
# 513     attack-RightWinger   left  SMI Sports Management
# 514  attack-Centre-Forward  right     ICM Stellar Sports
# 515  attack-Centre-Forward  right              Wasserman
# 516  attack-Centre-Forward  right              GOAL CLUB
# 517  attack-Centre-Forward   left               no agent
#
#                      club      joined     expire last_contract outfitter  sns  \
# 513  West Bromwich Albion    2021-1-8  2022-6-30     2019-8-31      Nike    2
# 514  West Bromwich Albion  2020-10-15  2026-6-30     2019-8-31    adidas    2
# 515  West Bromwich Albion    2020-9-9  2025-6-30     2019-8-31    adidas    2
# 516  West Bromwich Albion   2021-1-29  2021-6-30     2019-8-31    adidas    1
# 517  West Bromwich Albion   2016-8-31  2021-6-30      2017-7-6    adidas    2
#
#      caps_goals  Apps  Mins Tackles Inter Fouls Offsides Clear Drbed Blocks  \
# 513         4.0  0(1)     9       0     0     0        0     0     1      0
# 514         NaN  1(1)     3       1     0   0.5        0     0     0      0
# 515        17.0     1    90       0     0     0        0     0     0      0
# 516         NaN     1    90       0     0     0        0     0     0      0
# 517         9.2     1    90       5     0     1        1     3     0      0
#
#     OwnG  Rating_x     Position         Team  Age Assists KeyP  AvgP   PS%  \
# 513    0      5.74     AM(C),FW      Man Utd   31       0    0   2.0   100
# 514    0      5.68   Midfielder  Southampton   19       0    0   1.5  66.7
# 515    0      5.65           GK       Fulham   24       0    0  25.0    76
# 516    0      5.41           GK      Chelsea   39       0    0  24.0  91.7
# 517    0      5.06     Defender  Southampton   20       0    0  19.0  78.9
#
#     Crosses LongB ThrB  Rating_y Goals SpG Drb Fouled Off Disp UnsTch
# 513       0     0    0      5.74     0   0   0      0   0    2      1
# 514       0     0    0      5.68     0   0   0    0.5   0    0    0.5
# 515       0     8    0      5.65     0   0   0      0   0    0      0
# 516       0     2    0      5.41     0   0   0      0   0    0      0
# 517       0     0    0      5.06     0   0   0      0   0    0      0

# %%
test = premier_df.drop(columns=["caps_goals", "Apps", "Mins", "Position", "Team", "Age"])

# %%
msno.bar(test)
# Out:
# <AxesSubplot:>

# %%
test[test['market_value'].isnull()]
# Out:
#                    name  market_value app conceded_goals clean_sheets  \
# 106       AnthonyElanga           NaN  15              7            2
# 213  AndreasSöndergaard           NaN  16             21            7
#
#     yellow_card second_yell red_card age height  citizenship  \
# 106           0           0        0  19    178            1
# 213           0           0        0  20    188            1
#
#               position   foot                   agent  \
# 106  attack-LeftWinger  right     ICM Stellar Sports
# 213         Goalkeeper  right  New Era Global Sports
#
#                             club     joined     expire last_contract  \
# 106        Manchester United U23   2020-7-1       None     2021-3-16
# 213  Wolverhampton Wanderers U23  2018-1-26  2023-6-30    2020-12-17
#
#     outfitter  sns Tackles Inter Fouls Offsides Clear Drbed Blocks OwnG  \
# 106      Nike    2     1.3   1.9   0.9      0.5   4.3   0.6    0.4    0
# 213      Puma    1     1.3   0.9   1.1      0.1   0.9   1.1    0.1    0
#
#      Rating_x Assists KeyP  AvgP   PS% Crosses LongB ThrB  Rating_y Goals  \
# 106      6.89       0  0.1  52.3  81.3     0.2   4.3    0      6.89     3
# 213      6.68       0  0.5  46.7  86.3       0   2.0    0      6.68     0
#
#      SpG  Drb Fouled Off Disp UnsTch
# 106  0.9  0.4    0.4   0  0.1    0.4
# 213  0.7  0.4    0.6   0  0.2    0.4

# %%
test[test['app'].isnull()]
# Out:
#                  name  market_value   app conceded_goals clean_sheets  \
# 74   CharlyMusondaJr.      900000.0  None           None         None
# 83       SergioRomero     1350000.0  None           None         None
# 90          PhilJones     4500000.0  None           None         None
# 198      MuhamedBesic     1800000.0  None           None         None
# 235     RenatDadashov      270000.0  None           None         None
# 319        SamMcQueen      720000.0  None           None         None
# 402        OuasimBouy      270000.0  None           None         None
# 421    NathanFerguson     3600000.0  None           None         None
# 445        SimonMoore      360000.0  None           None         None
#
#     yellow_card second_yell red_card age height  citizenship  \
# 74         None        None     None  24    173            1
# 83         None        None     None  34    192            1
# 90         None        None     None  29    185            1
# 198        None        None     None  28    180            1
# 235        None        None     None  21    186            1
# 319        None        None     None  26    181            1
# 402        None        None     None  27    181            1
# 421        None        None     None  20    184            1
# 445        None        None     None  30    191            1
#
#                        position   foot  \
# 74   midfield-AttackingMidfield  right
# 83                   Goalkeeper  right
# 90         Defender-Centre-Back  right
# 198  midfield-DefensiveMidfield  right
# 235       attack-Centre-Forward  right
# 319          Defender-Left-Back   left
# 402  midfield-DefensiveMidfield   left
# 421        Defender-Centre-Back  right
# 445                  Goalkeeper  right
#
#                                       agent                     club  \
# 74                      ICM Stellar Sports                Chelsea FC
# 83                      ICM Stellar Sports         Manchester United
# 90                               Wasserman         Manchester United
# 198                               no agent                Everton FC
# 235                 Universal Sports Group   Wolverhampton Wanderers
# 319                             New Vision            Southampton FC
# 402                            Mino Raiola              Leeds United
# 421  Sport Avenir Management International            Crystal Palace
# 445                              Wasserman          Sheffield United
#
#         joined     expire last_contract outfitter  sns Tackles Inter Fouls  \
# 74    2017-7-1  2022-6-30     2017-12-8      Nike    1     2.1   1.6   1.1
# 83   2015-7-27  2021-6-30     2017-7-16    adidas    2     1.6   0.6     1
# 90    2011-7-1  2023-6-30      2019-2-8    adidas    1       2   3.0     1
# 198  2014-7-28  2021-6-30     2016-2-29      Nike    3     1.7   1.8   0.9
# 235   2019-8-6  2023-6-30     2020-10-3      Nike    1     0.6   1.2   0.9
# 319   2016-7-1  2021-6-30     2016-12-5      Nike    2     1.0   0.5   0.8
# 402   2017-8-1  2021-6-30      2019-9-9      Nike    1     0.2   0.2   0.2
# 421  2020-7-27  2023-6-30     2020-8-21      Puma    1     0.9   0.5   0.9
# 445  2016-8-19  2021-6-30     2018-7-26      Nike    1     0.3   0.3   0.5
#
#     Offsides Clear Drbed Blocks OwnG  Rating_x Assists KeyP  AvgP   PS%  \
# 74         0   0.8   1.6    0.2    0      6.96       1  0.8  64.8  89.3
# 83       0.1   1.2   0.7    0.2    0      6.93       2  1.3  50.6  88.1
# 90         0   1.0     0      0    0      6.92       0    2  66.0  90.9
# 198      0.4   4.4   0.6    0.4    0      6.71       0    0  34.4  75.1
# 235        0   0.8   0.8    0.3    0      6.64       3  1.3  53.4  78.7
# 319        0   0.6   0.9    0.1    0      6.50       1  0.5  35.3  85.6
# 402        0     0   0.7      0    0      6.30       0  0.4  11.4  80.6
# 421      0.1   0.9   1.2    0.3    0      6.24       2  0.7  36.8  84.1
# 445        0   0.8   0.1      0    0      6.19       0  0.2  11.7  75.2
#
#     Crosses LongB ThrB  Rating_y Goals  SpG  Drb Fouled  Off Disp UnsTch
# 74      0.1   2.6    0      6.96     6  0.5  0.5    1.1    0  0.4    0.6
# 83      1.1   2.3    0      6.93     1  1.1    1    0.6    0  0.7    0.9
# 90        1   1.0    0      6.92     0    1    2      0    1    2      0
# 198       0   3.1    0      6.71     1  0.6  0.1    0.2    0    0    0.2
# 235     1.2   4.3    0      6.64     2  0.5  0.3    1.2    0  0.3    0.8
# 319     0.4   1.2    0      6.50     0  0.5  0.3    0.5    0  0.5    0.5
# 402       0   0.1    0      6.30     1    1  0.2    0.7  0.1  0.7    1.1
# 421     0.4   1.9    0      6.24     0  0.7  0.6    0.7    0  0.7    1.1
# 445       0   0.1    0      6.19     1  0.9  0.5    0.7  0.3  0.8    1.7

# %%
test[test['expire'].isnull()]
# Out:
#               name  market_value app conceded_goals clean_sheets yellow_card  \
# 31    RhysWilliams     4500000.0   3              1            0           1
# 106  AnthonyElanga           NaN  15              7            2           0
#
#     second_yell red_card age height  citizenship              position   foot  \
# 31            0        0  20    195            1  Defender-Centre-Back  right
# 106           0        0  19    178            1     attack-LeftWinger  right
#
#                    agent                   club    joined expire  \
# 31   ICM Stellar Sports        Liverpool FC U23  2019-7-1   None
# 106  ICM Stellar Sports   Manchester United U23  2020-7-1   None
#
#     last_contract outfitter  sns Tackles Inter Fouls Offsides Clear Drbed  \
# 31      2019-2-26    adidas    1     1.4   0.7   1.3      0.1   1.2   0.4
# 106     2021-3-16      Nike    2     1.3   1.9   0.9      0.5   4.3   0.6
#
#     Blocks OwnG  Rating_x Assists KeyP  AvgP   PS% Crosses LongB ThrB  \
# 31     0.3    1      7.09       5  2.3  50.3  85.2     1.9   0.9    0
# 106    0.4    0      6.89       0  0.1  52.3  81.3     0.2   4.3    0
#
#      Rating_y Goals  SpG  Drb Fouled  Off Disp UnsTch
# 31       7.09     1  0.3  1.1    0.8  0.1  0.6    0.8
# 106      6.89     3  0.9  0.4    0.4    0  0.1    0.4

# %%
sns.distplot(test['market_value'])
# Out:
# <AxesSubplot:xlabel='market_value', ylabel='Density'>
